# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np

# %%
path = './input/'
filename = path + '001_vint_trace_27957.wav'

# %%
f = open(filename)
lines = f.read().splitlines()
f.close()
for i, line in enumerate(lines):
    if i < 10:
        print(i, line)
# Out:
# 0 THIS IS A WAVELET LISTING
# 1 Header :   001 vint_trace_27957
# 2 Sample interval (msec) = 24
# 3 Number of samples      376
# 4 Index of time zero     1
# 5 1.5356692E+03 1.5356692E+03 1.5356692E+03 1.5356692E+03 1.5356692E+03 1.5356692E+03
# 6 1.5356692E+03 1.5356692E+03 1.8573135E+03 1.9468926E+03 2.0360549E+03 2.1228533E+03
# 7 2.2054456E+03 2.2823022E+03 2.3520679E+03 2.4136123E+03 2.4658582E+03 2.5081274E+03
# 8 2.5567061E+03 2.5956733E+03 2.6254463E+03 2.6469285E+03 2.6612676E+03 2.6698186E+03
# 9 2.6738682E+03 2.6746157E+03 2.6730513E+03 2.6699751E+03 2.6659429E+03 2.6614238E+03

# %%
df_raw = pd.DataFrame()

# %%
column_names = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6']

# %%
rowstoskip = 5
sample_rate = 24

# %%
df_raw = pd.read_csv(filename, names=column_names, skiprows=rowstoskip, delim_whitespace=True)
#df_raw = pd.read_csv(filename, names=column_names, skiprows=rowstoskip, delim_whitespace=True)

# %%
df_stacked = df_raw.stack().reset_index()

# %%
df_stacked = df_stacked.drop(['level_0', 'level_1'], axis=1)

# %%
df_stacked.columns = ['Vp']

# %%
df_raw = df_stacked

# %%
df_raw['delta TWT'] = sample_rate

# %%
df_raw['TWT'] = df_raw['delta TWT'].cumsum(axis=0)

# %%
df_raw['delta Depth'] = df_raw['Vp'] * df_raw['delta TWT'] / 2000

# %%
df_raw['Depth'] = df_raw['delta Depth'].cumsum(axis=0)

# %%
df_raw
# Out:
#             Vp  delta TWT   TWT  delta Depth         Depth
# 0    1535.6692         24    24    18.428030     18.428030
# 1    1535.6692         24    48    18.428030     36.856061
# 2    1535.6692         24    72    18.428030     55.284091
# 3    1535.6692         24    96    18.428030     73.712122
# 4    1535.6692         24   120    18.428030     92.140152
# 5    1535.6692         24   144    18.428030    110.568182
# 6    1535.6692         24   168    18.428030    128.996213
# 7    1535.6692         24   192    18.428030    147.424243
# 8    1857.3135         24   216    22.287762    169.712005
# 9    1946.8926         24   240    23.362711    193.074716
# 10   2036.0549         24   264    24.432659    217.507375
# 11   2122.8533         24   288    25.474240    242.981615
# 12   2205.4456         24   312    26.465347    269.446962
# 13   2282.3022         24   336    27.387626    296.834588
# 14   2352.0679         24   360    28.224815    325.059403
# 15   2413.6123         24   384    28.963348    354.022751
# 16   2465.8582         24   408    29.590298    383.613049
# 17   2508.1274         24   432    30.097529    413.710578
# 18   2556.7061         24   456    30.680473    444.391051
# 19   2595.6733         24   480    31.148080    475.539131
# 20   2625.4463         24   504    31.505356    507.044486
# 21   2646.9285         24   528    31.763142    538.807628
# 22   2661.2676         24   552    31.935211    570.742840
# 23   2669.8186         24   576    32.037823    602.780663
# 24   2673.8682         24   600    32.086418    634.867081
# 25   2674.6157         24   624    32.095388    666.962470
# 26   2673.0513         24   648    32.076616    699.039085
# 27   2669.9751         24   672    32.039701    731.078786
# 28   2665.9429         24   696    31.991315    763.070101
# 29   2661.4238         24   720    31.937086    795.007187
# ..         ...        ...   ...          ...           ...
# 346  7238.7734         24  8328    86.865281  21534.438718
# 347  7244.2656         24  8352    86.931187  21621.369905
# 348  7249.7266         24  8376    86.996719  21708.366624
# 349  7255.1523         24  8400    87.061828  21795.428452
# 350  7260.5352         24  8424    87.126422  21882.554874
# 351  7265.8828         24  8448    87.190594  21969.745468
# 352  7271.2031         24  8472    87.254437  22056.999905
# 353  7276.4844         24  8496    87.317813  22144.317718
# 354  7281.7266         24  8520    87.380719  22231.698437
# 355  7286.9297         24  8544    87.443156  22319.141593
# 356  7292.1055         24  8568    87.505266  22406.646859
# 357  7297.2461         24  8592    87.566953  22494.213812
# 358  7302.3477         24  8616    87.628172  22581.841985
# 359  7307.4180         24  8640    87.689016  22669.531001
# 360  7312.4531         24  8664    87.749437  22757.280438
# 361  7317.4570         24  8688    87.809484  22845.089922
# 362  7322.4297         24  8712    87.869156  22932.959078
# 363  7327.3633         24  8736    87.928360  23020.887438
# 364  7332.2656         24  8760    87.987187  23108.874625
# 365  7337.1367         24  8784    88.045640  23196.920266
# 366  7341.9766         24  8808    88.103719  23285.023985
# 367  7346.7852         24  8832    88.161422  23373.185407
# 368  7351.5586         24  8856    88.218703  23461.404110
# 369  7356.2188         24  8880    88.274626  23549.678736
# 370  7359.7773         24  8904    88.317328  23637.996064
# 371  7358.0664         24  8928    88.296797  23726.292860
# 372  7346.3672         24  8952    88.156406  23814.449267
# 373  7337.2109         24  8976    88.046531  23902.495798
# 374  7370.4492         24  9000    88.445390  23990.941188
# 375  7375.4258         24  9024    88.505110  24079.446298
#
# [376 rows x 5 columns]

# %%
df_raw.plot(x='Vp', y=['TWT', 'Depth'], figsize=(16, 12), grid=True, ylim=(6000, 0), xlim=(0, 6000) );
#df_raw.plot(x='Vp', y='Depth', figsize=(16, 12), grid=True)

# %%
filename_000 = path + '000_SF.txt'
filename_065 = path + '065_BTRT.txt'
filename_090 = path + '090_TTUR.txt'
filename_160 = path + '160_TJUR.txt'
filename_200 = path + '200_BED.txt'
filename_210 = path + '210_SOL.txt'
filename_230 = path + '230_T_COSS.txt'
filename_255 = path + '255_D_PERM.txt'

# %%
df_raw_000 = pd.DataFrame()
df_raw_065 = pd.DataFrame()
df_raw_090 = pd.DataFrame()
df_raw_160 = pd.DataFrame()
df_raw_200 = pd.DataFrame()
df_raw_210 = pd.DataFrame()
df_raw_230 = pd.DataFrame()
df_raw_255 = pd.DataFrame()

# %%
df_raw_000 = pd.read_csv(filename_000, delim_whitespace=True)
df_raw_065 = pd.read_csv(filename_065, delim_whitespace=True)
df_raw_090 = pd.read_csv(filename_090, delim_whitespace=True)
df_raw_160 = pd.read_csv(filename_160, delim_whitespace=True)
df_raw_200 = pd.read_csv(filename_200, delim_whitespace=True)
df_raw_210 = pd.read_csv(filename_210, delim_whitespace=True)
df_raw_230 = pd.read_csv(filename_230, delim_whitespace=True)
df_raw_255 = pd.read_csv(filename_255, delim_whitespace=True)

# %%
df_raw_000['File'] = '000_SF'
df_raw_065['File'] = '065_BTRT'
df_raw_090['File'] = '090_TTUR'
df_raw_160['File'] = '160_TJUR'
df_raw_200['File'] = '200_BED'
df_raw_210['File'] = '210_SOL'
df_raw_230['File'] = '230_T_CROSS'
df_raw_255['File'] = '255_D_PERM'

# %%
#df_raw_000

# %%
df_horizons = pd.concat([df_raw_000, df_raw_065, df_raw_090, df_raw_160, df_raw_200, df_raw_210, df_raw_230, df_raw_255])

# %%
plt.figure(figsize=(16, 12))
sns.set_style("whitegrid")
plt.gca().invert_yaxis()
sns.regplot(x='X_km', y='Z_floor', data=df_horizons, fit_reg=False);
